# %%
import os
import random
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import cv2
import imutils
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, ImageDataGenerator, array_to_img
from tensorflow.keras.applications import EfficientNetB1

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, GlobalAveragePooling2D, Flatten, Dropout, Dense

# %%
train_dir = '../../dataset_26'

classes = os.listdir(train_dir) 
# classes = ['no_tumor', 'glioma_tumor', 'meningioma_tumor', 'pituitary_tumor']

os.mkdir('content/Train-Data')

for cls in classes:
  os.mkdir(f'content/Train-Data/{cls}')

# %%
classes
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
train_files_path = {cls: list(map(lambda x: os.path.join(train_dir, cls, x), os.listdir(os.path.join(train_dir, cls)))) for cls in classes}

# %%
for cls in classes:
  plt.figure(figsize=(17, 17))
  random.shuffle(train_files_path[cls])
  files = train_files_path[cls][:5]

  for i in range(1, 5):
    plt.subplot(4, 4, i)
    plt.imshow(load_img(files[i]))
    plt.title(cls)

# %%
def crop_image(image, plot=False):
    
    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    img_gray = cv2.GaussianBlur(img_gray, (5, 5), 0)
    
    img_thresh = cv2.threshold(img_gray, 45, 255, cv2.THRESH_BINARY)[1]
    img_thresh = cv2.erode(img_thresh, None, iterations=2)
    img_thresh = cv2.dilate(img_thresh, None, iterations=2)

    contours = cv2.findContours(img_thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = imutils.grab_contours(contours)
    c = max(contours, key=cv2.contourArea)

    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])
    
    new_image = image[extTop[1]:extBot[1], extLeft[0]:extRight[0]]            

    if plot:
        plt.figure()
        plt.subplot(1, 2, 1)
        plt.imshow(image)
        plt.tick_params(axis='both', which='both', top=False, bottom=False, left=False, right=False,labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        plt.title('Original Image')
        plt.subplot(1, 2, 2)
        plt.imshow(new_image)
        plt.tick_params(axis='both', which='both',top=False, bottom=False, left=False, right=False,labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        plt.title('Cropped Image')
        plt.show()
    
    return new_image

# %%
# glioma = os.path.join(train_dir, 'glioma_tumor')
# meningioma = os.path.join(train_dir, 'meningioma_tumor')
# pituitary = os.path.join(train_dir, 'pituitary_tumor')
# no_tumor = os.path.join(train_dir, 'no_tumor')

### All above paths to train class directories in the following list
train_class_paths = [os.path.join(train_dir, cls) for cls in classes]
print(train_class_paths)

# test_class_paths = [os.path.join(test_dir, cls) for cls in classes]
# Out:
# ['../../dataset_26\\glioma', '../../dataset_26\\meningioma', '../../dataset_26\\notumor', '../../dataset_26\\pituitary']

# %%
def crop_img_saver(class_read_paths, save_dir):
  save_root = 'content'
  for cls in class_read_paths:
    for i, p in tqdm(enumerate(os.listdir(cls))):
      path = os.path.join(cls, p)
      img = crop_image(cv2.imread(path), plot=False)

      if img is not None:
        img = cv2.resize(img, (224, 224))
        save_class = cls.split('\\')[-1]
        print(save_class)
        save_path = os.path.join(save_dir, save_class, f'{str(i)}.jpg')
        print(save_path)
        cv2.imwrite(save_path, img)

# %%
crop_img_saver(train_class_paths, save_dir='Train-Data/')
# Out:
# 58it [00:00, 286.14it/s]
# glioma
# Train-Data/glioma\0.jpg
# glioma
# Train-Data/glioma\1.jpg
# glioma
# Train-Data/glioma\2.jpg
# glioma
# Train-Data/glioma\3.jpg
# glioma
# Train-Data/glioma\4.jpg
# glioma
# Train-Data/glioma\5.jpg
# glioma
# Train-Data/glioma\6.jpg
# glioma
# Train-Data/glioma\7.jpg
# glioma
# Train-Data/glioma\8.jpg
# glioma
# Train-Data/glioma\9.jpg
# glioma
# Train-Data/glioma\10.jpg
# glioma
# Train-Data/glioma\11.jpg
# glioma
# Train-Data/glioma\12.jpg
# glioma
# Train-Data/glioma\13.jpg
# glioma
# Train-Data/glioma\14.jpg
# glioma
# Train-Data/glioma\15.jpg
# glioma
# Train-Data/glioma\16.jpg
# glioma
# Train-Data/glioma\17.jpg
# glioma
# Train-Data/glioma\18.jpg
# glioma
# Train-Data/glioma\19.jpg
# glioma
# Train-Data/glioma\20.jpg
# glioma
# Train-Data/glioma\21.jpg
# glioma
# Train-Data/glioma\22.jpg
# glioma
# Train-Data/glioma\23.jpg
# glioma
# Train-Data/glioma\24.jpg
# glioma
# Train-Data/glioma\25.jpg
# glioma
# Train-Data/glioma\26.jpg
# glioma
# Train-Data/glioma\27.jpg
# glioma
# Train-Data/glioma\28.jpg
# glioma
# Train-Data/glioma\29.jpg
# glioma
# Train-Data/glioma\30.jpg
# glioma
# Train-Data/glioma\31.jpg
# glioma
# Train-Data/glioma\32.jpg
# glioma
# Train-Data/glioma\33.jpg
# glioma
# Train-Data/glioma\34.jpg
# glioma
# Train-Data/glioma\35.jpg
# glioma
# Train-Data/glioma\36.jpg
# glioma
# Train-Data/glioma\37.jpg
# glioma
# Train-Data/glioma\38.jpg
# glioma
# Train-Data/glioma\39.jpg
# glioma
# Train-Data/glioma\40.jpg
# glioma
# Train-Data/glioma\41.jpg
# glioma
# Train-Data/glioma\42.jpg
# glioma
# Train-Data/glioma\43.jpg
# glioma
# Train-Data/glioma\44.jpg
# glioma
# Train-Data/glioma\45.jpg
# glioma
# Train-Data/glioma\46.jpg
# glioma
# Train-Data/glioma\47.jpg
# glioma
# Train-Data/glioma\48.jpg
# glioma
# Train-Data/glioma\49.jpg
# glioma
# Train-Data/glioma\50.jpg
# glioma
# Train-Data/glioma\51.jpg
# glioma
# Train-Data/glioma\52.jpg
# glioma
# Train-Data/glioma\53.jpg
# glioma
# Train-Data/glioma\54.jpg
# glioma
# Train-Data/glioma\55.jpg
# glioma
# Train-Data/glioma\56.jpg
# glioma
# Train-Data/glioma\57.jpg
# 120it [00:00, 322.96it/s]
# glioma
# Train-Data/glioma\58.jpg
# Train-Data/pituitary\72.jpg
# pituitary
# Train-Data/pituitary\73.jpg
# pituitary
# Train-Data/pituitary\74.jpg
# pituitary
# Train-Data/pituitary\75.jpg
# pituitary
# Train-Data/pituitary\76.jpg
# pituitary
# Train-Data/pituitary\77.jpg
# 86it [00:00, 262.93it/s]
# pituitary
# Train-Data/pituitary\78.jpg
# pituitary
# Train-Data/pituitary\79.jpg
# pituitary
# Train-Data/pituitary\80.jpg
# pituitary
# Train-Data/pituitary\81.jpg
# pituitary
# Train-Data/pituitary\82.jpg
# pituitary
# Train-Data/pituitary\83.jpg
# pituitary
# Train-Data/pituitary\84.jpg
# pituitary
# Train-Data/pituitary\85.jpg
# pituitary
# Train-Data/pituitary\86.jpg
# pituitary
# Train-Data/pituitary\87.jpg
# pituitary
# Train-Data/pituitary\88.jpg
# pituitary
# Train-Data/pituitary\89.jpg
# pituitary
# Train-Data/pituitary\90.jpg
# pituitary
# Train-Data/pituitary\91.jpg
# pituitary
# Train-Data/pituitary\92.jpg
# pituitary
# Train-Data/pituitary\93.jpg
# pituitary
# Train-Data/pituitary\94.jpg
# pituitary
# Train-Data/pituitary\95.jpg
# pituitary
# Train-Data/pituitary\96.jpg
# pituitary
# Train-Data/pituitary\97.jpg
# pituitary
# Train-Data/pituitary\98.jpg
# pituitary
# Train-Data/pituitary\99.jpg
# pituitary
# Train-Data/pituitary\100.jpg
# pituitary
# Train-Data/pituitary\101.jpg
# pituitary
# Train-Data/pituitary\102.jpg
# pituitary
# Train-Data/pituitary\103.jpg
# pituitary
# Train-Data/pituitary\104.jpg
# pituitary
# Train-Data/pituitary\105.jpg
# 120it [00:00, 260.87it/s]
# pituitary
# Train-Data/pituitary\106.jpg
# pituitary
# Train-Data/pituitary\107.jpg
# pituitary
# Train-Data/pituitary\108.jpg
# pituitary
# Train-Data/pituitary\109.jpg
# pituitary
# Train-Data/pituitary\110.jpg
# pituitary
# Train-Data/pituitary\111.jpg
# pituitary
# Train-Data/pituitary\112.jpg
# pituitary
# Train-Data/pituitary\113.jpg
# pituitary
# Train-Data/pituitary\114.jpg
# pituitary
# Train-Data/pituitary\115.jpg
# pituitary
# Train-Data/pituitary\116.jpg
# pituitary
# Train-Data/pituitary\117.jpg
# pituitary
# Train-Data/pituitary\118.jpg
# pituitary
# Train-Data/pituitary\119.jpg

# %%
train_data_generator = ImageDataGenerator(rotation_range=10, 
                                          height_shift_range=0.2, 
                                          horizontal_flip=True, 
                                          validation_split=0.2)

train_data = train_data_generator.flow_from_directory('content/Train-Data',
                                                      target_size=(224, 224),
                                                      batch_size=32,
                                                      class_mode='categorical',
                                                      subset='training')

validation_data = train_data_generator.flow_from_directory('content/Train-Data',
                                                           target_size=(224, 224),
                                                           batch_size=32,
                                                           class_mode='categorical',
                                                           subset='validation')
# Out:
# Found 0 images belonging to 4 classes.
# Found 0 images belonging to 4 classes.
